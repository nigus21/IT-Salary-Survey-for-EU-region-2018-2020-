# %%
import pandas as pd

# %%
dataset = pd.read_csv("IT Salary Survey EU  2020.csv")

# %%
dataset.head()
# Out:
#              Timestamp   Age Gender    City           Position   \
# 0  24/11/2020 11:14:15  26.0   Male  Munich   Software Engineer
# 1  24/11/2020 11:14:16  26.0   Male  Berlin   Backend Developer
# 2  24/11/2020 11:14:21  29.0   Male  Berlin   Software Engineer
# 3  24/11/2020 11:15:24  28.0   Male  Berlin  Frontend Developer
# 4  24/11/2020 11:15:46  37.0   Male  Berlin   Backend Developer
#
#   Total years of experience Years of experience in Germany Seniority level  \
# 0                         5                              3          Senior
# 1                         7                              4          Senior
# 2                        12                              6            Lead
# 3                         4                              1          Junior
# 4                        17                              6          Senior
#
#   Your main technology / programming language  \
# 0                                  TypeScript
# ...

# %%
dataset.tail()
# Out:
#                 Timestamp   Age Gender         City  \
# 1248  18/01/2021 15:05:50  31.0   Male       Berlin
# 1249  18/01/2021 17:46:02  33.0   Male       Berlin
# 1250  18/01/2021 23:20:35  39.0   Male       Munich
# 1251  19/01/2021 10:17:58  26.0   Male  Saarbrücken
# 1252  19/01/2021 12:01:11  26.0   Male       Berlin
#
#                                    Position  Total years of experience  \
# 1248                       Backend Developer                         9
# 1249  Researcher/ Consumer Insights Analyst                         10
# 1250                   IT Operations Manager                        15
# 1251                      Frontend Developer                         7
# 1252                                  DevOps                         2
#
#      Years of experience in Germany Seniority level  \
# 1248                              5          Senior
# 1249                            1.5          Senior
# 1250                              2            Lead
# ...

# %%
import pandas as pd

# %%
import pandas as pd
import numpy as np
import seaborn as sns
# Out:
# Matplotlib is building the font cache; this may take a moment.

# %%
dataset.shape
# Out:
# (1253, 23)

# %%
dataset.describe()
# Out:
#                Age  Yearly brutto salary (without bonus and stocks) in EUR  \
# count  1226.000000                                       1.253000e+03
# mean     32.509788                                       8.027904e+07
# std       5.663804                                       2.825061e+09
# min      20.000000                                       1.000100e+04
# 25%      29.000000                                       5.880000e+04
# 50%      32.000000                                       7.000000e+04
# 75%      35.000000                                       8.000000e+04
# max      69.000000                                       1.000000e+11
#
#        Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country  \
# count                                       8.850000e+02
# mean                                        6.322459e+05
# std                                         1.680508e+07
# ...

# %%
dataset.columns
# Out:
# Index(['Timestamp', 'Age', 'Gender', 'City', 'Position ',
#        'Total years of experience', 'Years of experience in Germany',
#        'Seniority level', 'Your main technology / programming language',
#        'Other technologies/programming languages you use often',
#        'Yearly brutto salary (without bonus and stocks) in EUR',
#        'Yearly bonus + stocks in EUR',
#        'Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country',
#        'Annual bonus+stocks one year ago. Only answer if staying in same country',
#        'Number of vacation days', 'Employment status', 'Сontract duration',
#        'Main language at work', 'Company size', 'Company type',
#        'Have you lost your job due to the coronavirus outbreak?',
#        'Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week',
# ...

# %%
dataset.nuniqe()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20232\1321523940.py in <module>
# ----> 1 dataset.nuniqe()
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in __getattr__(self, name)
#    5573         ):
#    5574             return self[name]
# -> 5575         return object.__getattribute__(self, name)
#    5576
#    5577     def __setattr__(self, name: str, value) -> None:
#
# AttributeError: 'DataFrame' object has no attribute 'nuniqe'

# %%
dataset.nunique()
# Out:
# Timestamp                                                                                                                  1248
# Age                                                                                                                          40
# Gender                                                                                                                        3
# City                                                                                                                        119
# Position                                                                                                                    148
# Total years of experience                                                                                                    48
# Years of experience in Germany                                                                                               53
# ...

# %%
dataset['gender'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'gender'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
dataset['Gender'].unique(0)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20232\2240316541.py in <module>
# ----> 1 dataset['Gender'].unique(0)
#
# TypeError: unique() takes 1 positional argument but 2 were given

# %%
dataset['Gender'].unique()
# Out:
# array(['Male', 'Female', nan, 'Diverse'], dtype=object)

# %%
dataset['Position'].unique()
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\pandas\core\indexes\base.py in get_loc(self, key, method, tolerance)
#    3628             try:
# -> 3629                 return self._engine.get_loc(casted_key)
#    3630             except KeyError as err:
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# ~\anaconda3\lib\site-packages\pandas\_libs\index.pyx in pandas._libs.index.IndexEngine.get_loc()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# pandas\_libs\hashtable_class_helper.pxi in pandas._libs.hashtable.PyObjectHashTable.get_item()
#
# KeyError: 'Position'
#
# The above exception was the direct cause of the following exception:
#
# KeyError                                  Traceback (most recent call last)
# ...

# %%
dataset['Seniority level'].unique()
# Out:
# array(['Senior', 'Lead', 'Junior', 'Middle', 'Head', nan, 'No level',
#        'VP', 'Manager', 'Work Center Manager', 'CTO', 'No level ',
#        'Director', 'Key', 'C-level executive manager', 'Principal',
#        'intern', 'Student', 'no idea, there are no ranges in the firm ',
#        'C-Level', 'Working Student', 'Entry level', 'Intern', 'student',
#        'Self employed'], dtype=object)

# %%
#cleaning the data

# %%
dataset.isnull().sum()
# Out:
# Timestamp                                                                                                                    0
# Age                                                                                                                         27
# Gender                                                                                                                      10
# City                                                                                                                         0
# Position                                                                                                                     6
# Total years of experience                                                                                                   16
# Years of experience in Germany                                                                                              32
# ...

# %%
newdata = dataset.dropna()

# %%
newdata.isnull()
# Out:
#       Timestamp    Age  Gender   City  Position   Total years of experience  \
# 35        False  False   False  False      False                      False
# 141       False  False   False  False      False                      False
# 221       False  False   False  False      False                      False
# 225       False  False   False  False      False                      False
# 276       False  False   False  False      False                      False
# ...         ...    ...     ...    ...        ...                        ...
# 1228      False  False   False  False      False                      False
# 1233      False  False   False  False      False                      False
# 1236      False  False   False  False      False                      False
# 1237      False  False   False  False      False                      False
# 1252      False  False   False  False      False                      False
#
#       Years of experience in Germany  Seniority level  \
# ...

# %%
newdata.isnull.sum()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_20232\2035448078.py in <module>
# ----> 1 newdata.isnull.sum()
#
# AttributeError: 'function' object has no attribute 'sum'

# %%
newdata.isnull().sum()
# Out:
# Timestamp                                                                                                                  0
# Age                                                                                                                        0
# Gender                                                                                                                     0
# City                                                                                                                       0
# Position                                                                                                                   0
# Total years of experience                                                                                                  0
# Years of experience in Germany                                                                                             0
# ...

# %%
newdata.drop(['Have you lost your job due to the coronavirus outbreak?' , 'Have you been forced to have a shorter working week (Kurzarbeit)? If yes, how many hours per week'], axis=1)
# Out:
#                 Timestamp   Age  Gender        City             Position   \
# 35    24/11/2020 11:28:14  33.0    Male      Berlin        Data Scientist
# 141   24/11/2020 12:09:03  34.0    Male      Munich       Cloud Architect
# 221   24/11/2020 13:33:08  32.0    Male   Stuttgart           QA Engineer
# 225   24/11/2020 13:37:57  24.0    Male  Boeblingen  C/C++/Java developer
# 276   24/11/2020 14:58:11  38.0    Male      Munich     Backend Developer
# ...                   ...   ...     ...         ...                   ...
# 1228  07/01/2021 10:47:40  28.0    Male      Munich     Software Engineer
# 1233  08/01/2021 17:23:19  33.0  Female      Munich           Testmanager
# 1236  11/01/2021 12:12:34  39.0    Male      Berlin           QA Engineer
# 1237  12/01/2021 12:48:23  37.0    Male      Berlin      Mobile Developer
# 1252  19/01/2021 12:01:11  26.0    Male      Berlin                DevOps
#
#      Total years of experience Years of experience in Germany Seniority level  \
# ...

# %%
newdata.shape
# Out:
# (144, 23)

# %%
# relationship analysis

# %%
corelation = newdata.corr()

# %%
sns.heatmap(corelation, xticklabels=corelation.columns,yticklabels=corelation.columns,annot=True)
# Out:
# <AxesSubplot:>

# %%
sns.pairplot(newdata)

# %%
newdata.describe()
# Out:
#               Age  Yearly brutto salary (without bonus and stocks) in EUR  \
# count  144.000000                                         144.000000
# mean    33.173611                                       74625.881944
# std      5.055399                                       24351.120077
# min     22.000000                                       14712.000000
# 25%     30.000000                                       60000.000000
# 50%     33.000000                                       74000.000000
# 75%     36.000000                                       84775.000000
# max     54.000000                                      180000.000000
#
#        Annual brutto salary (without bonus and stocks) one year ago. Only answer if staying in the same country  \
# count                                         144.000000
# mean                                        66752.756944
# std                                         18147.140439
# ...

# %%
## on the above we can see the difference.
